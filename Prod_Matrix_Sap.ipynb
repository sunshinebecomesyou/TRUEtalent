# %% [markdown]
# <a href="https://colab.research.google.com/github/sunshinebecomesyou/TRUEtalent/blob/main/Prod_Matrix_Sap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime
# !pip install XlsxWriter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 2.8 MB/s eta 0:00:00
# ...

# %%
df = pd.read_excel('/content/250725_ ZF1_Prod Matrix SAP.XLSX',keep_default_na=False)
# D_BNLN1 = pd.read_excel('/content/LN_LNPAR2.xls',keep_default_na=False)
# D_BNLN2 = pd.read_excel('/content/PAR_LNPAR2.xls')
# D_BNCD = pd.read_excel('/content/CDPAR2.xls')
# D_BNDD = pd.read_excel('/content/DDPAR2.xls')
# df

# %%
RAW = df
BNLN = df[df['Source System Basic Data'] == "BNLN"]
BNCD = df[df['Source System Basic Data'] == "BNCD"]
BNDD = df[df['Source System Basic Data'] == "BNDD"]
RAW
# Out:
#      Source System Basic Data Original Source Product Code Currency  \
# 0                        BNCD                           AA
# 1                        BNCD                           AB
# 2                        BNCD                           AC
# 3                        BNCD                           D1
# 4                        BNCD                           D2
# ...                       ...                          ...      ...
# 3947                     TRGV                       ZXXXXX
# 3948                     TRGV                      ZXXXXXA
# 3949                     TRGV                      ZXXXXXF
# 3950                     TRGV                      ZXXXXXH
# 3951                     TRGV                      ZXXXXXT
#
#       Product Segment  Revenue Owner Business Segment Exposure Calculation  \
# 0                 430            410                T                    N
# 1                 430            410                T                    N
# ...

# %%
today = datetime.today().strftime('%d-%m-%Y')
filename = f"Section Prod Matrix Sap {today}.xlsx"

with pd.ExcelWriter(filename, engine="xlsxwriter") as writer:
    RAW.to_excel(writer, sheet_name="RAW", index=False)
    BNLN.to_excel(writer, sheet_name="BNLN", index=False)
    BNCD.to_excel(writer, sheet_name="BNCD", index=False)
    BNDD.to_excel(writer, sheet_name="BNDD", index=False)

# %%
BNLN = df[df['Source System Basic Data'] == "BNLN"]

# Buat kolom baru berdasarkan keberadaan nilai pada 'Original Source Product Code' mengubah kolom menjadi none jika kosong dan sap jika true
# df_result['Original Source Product Code'] = df_result['Original Source Product Code'].notna().map({True: 'SAP', False: None})

# df_result = pd.merge(
#     D_BNLN1,
#     BNLN[['Original Source Product Code']],
#     left_on="PTYPE",
#     right_on="Original Source Product Code",
#     how='left'
# )
# print(BNLN.columns.tolist())

# 1. Rename kolom saat merge
df_result = pd.merge(
    D_BNLN1,
    BNLN[['Original Source Product Code']].rename(columns={'Original Source Product Code': 'SAP'}),
    left_on="PTYPE",
    right_on="SAP",
    how='left'
)

# Menyusun ulang kolom agar SAP tepat setelah PTYPE
cols = df_result.columns.tolist()
if 'SAP' in cols and 'PTYPE' in cols:
    cols.insert(cols.index('PTYPE') + 1, cols.pop(cols.index('SAP')))
    df_result = df_result[cols]

# df_result.to_excel("hasil_merge.xlsx", index=False)
df_result = df_result[df_result['SAP'].isna()]

df_result
# Out:
# Empty DataFrame
# Columns: [PTYPE, SAP, PSHDSC, PTYDSC, PLNGRP, PGRDSC, PGBOOK, PIBASE, PDEPTC, PCURTY, PBKDYS, PMINRT, PMAXRT, PRFLOR, PRCEIL, PINCLU, PFREQ, PFCODE, PPMTCD, PLATCD, PPDNOT, PCDNOT, PCPN, PMINCG, PCLASS, PPRCPM, P1MMPD, P2MMPD, P3MMPD, P4MMPD, P5MMPD, P6MMPD, P1DDPD, P2DDPD, P3DDPD, P4DDPD, P5DDPD, P6DDPD, PPDRPT, PMAXLC, PMNNEW, PRHSNW, PRHSPD, PRHSPO, PDHSDY, PBLNDY, POTOL, PMTBOA, PTAKLC, PRDTBK, PRDTDL, PRDTCL, PRDTAH, PRDTMS, PRDTTT, PRLDBK, PRLDDL, PRLDCL, PRLDAH, PRLDMS, PRLDTT, PRMEBK, PRMEDL, PRMECL, PRMEAH, PRMEMS, PRMETT, PRMTBK, PRMTDL, PRMTCL, PRMTAH, PRMTMS, PRMTTT, PMNRBK, PMNRDL, PMNRCL, PMNRAH, PMNRMS, PMNRTT, PRCABK, PREXBK, PREXDL, PREXCL, PREXAH, PREXMS, PREXTT, PPRCNO, PBLLBR, PRBEXF, PPRRTC, PDCBTR, PMIAMR, PLCTYP, PALTSC, PALTRT, PHMAIL, PRMIND, PTITLE, PCLSZR, PSTATU, ...]
# Index: []
#
# [0 rows x 240 columns]

# %%
BNCD = df[df['Source System Basic Data'] == "BNCD"]
# BNDD = df[df['Source System Basic Data'] == "BNDD"]
# df = df[df['Single-Character Flag'] == 'U']
# print(df.columns.tolist())
# BNCD = BNDCD[BNCD[]]
# BNCD
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>
